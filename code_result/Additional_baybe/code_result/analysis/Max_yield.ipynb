# %%
import pandas as pd
import ast
import numpy as np

# %%
print('== BayBE_mordred ==')
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl', 'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3',
                  'Reaction_OCH2F', 'Reaction_P', 'Reaction_Si']
for data in All_data_names:
    df = pd.read_csv(f"../results/BOsearch_mordred/BOsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == BayBE_mordred ==
# Reaction_CO_1.5h: avg=10.08, std=5.22
# Reaction_CO_biphenyl: avg=8.30, std=2.30
# Reaction_CO_ortho: avg=17.02, std=3.79
# Reaction_CO_Cl: avg=3.02, std=1.12
# Reaction_CS: avg=7.00, std=4.20
# Reaction_CN: avg=11.03, std=4.25
# Reaction_2+2: avg=32.38, std=9.25
# Reaction_CF3: avg=30.67, std=11.43
# Reaction_CH2CF3: avg=21.70, std=4.81
# Reaction_CH2F: avg=22.75, std=5.91
# Reaction_Cy: avg=16.03, std=8.18
# Reaction_SCF3: avg=40.77, std=12.59
# Reaction_OCH2F: avg=13.10, std=4.01
# Reaction_P: avg=9.08, std=3.24
# Reaction_Si: avg=19.08, std=7.72

# %%
print('== BayBE_DFT ==')
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl', 'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3',
                  'Reaction_OCH2F', 'Reaction_P', 'Reaction_Si']
for data in All_data_names:
    df = pd.read_csv(f"../results/BOsearch_DFT/BOsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# == BayBE_DFT ==
# Reaction_CO_1.5h: avg=28.32, std=13.02
# Reaction_CO_biphenyl: avg=22.47, std=6.13
# Reaction_CO_ortho: avg=12.27, std=10.98
# Reaction_CO_Cl: avg=24.15, std=9.24
# Reaction_CS: avg=22.33, std=13.93
# Reaction_CN: avg=6.63, std=5.36
# Reaction_2+2: avg=22.13, std=11.07
# Reaction_CF3: avg=29.52, std=14.23
# Reaction_CH2CF3: avg=28.50, std=8.72
# Reaction_CH2F: avg=21.08, std=7.60
# Reaction_Cy: avg=27.05, std=15.75
# Reaction_SCF3: avg=24.33, std=9.98
# Reaction_OCH2F: avg=13.15, std=4.60
# Reaction_P: avg=22.48, std=10.74
# Reaction_Si: avg=36.12, std=12.40
