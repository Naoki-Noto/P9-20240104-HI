# %%
from ModelbaseSearch_TL import TrABsearch
from xgboost import XGBRegressor as xgb
from lightgbm import LGBMRegressor as lgbm

# %%
for data in ['Reaction_P']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=3,
               es=xgb(), result_dir="../results/TrABsearch_top3_e0_ne5_XGB")
# Out:
# Running TrABsearch for Reaction_P...

# %%
for data in ['Reaction_P']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=3,
               es=lgbm(verbose=-1), result_dir="../results/TrABsearch_top3_e0_ne5_LGBM")
# Out:
# Running TrABsearch for Reaction_P...

# %%
for data in ['Reaction_P']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=3,
               data_dir="../../data/data_MF", result_dir="../results/TrABsearch_top3_e0_ne5_MF")
# Out:
# Running TrABsearch for Reaction_P...
