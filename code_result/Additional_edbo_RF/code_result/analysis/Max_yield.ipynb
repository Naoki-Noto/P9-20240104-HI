# %%
import pandas as pd
import ast
import numpy as np

# %%
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3',
                  'Reaction_OCH2F', 'Reaction_P', 'Reaction_Si']
for data in All_data_names:
    df = pd.read_csv(f"../results/BOsearch_PI/BOsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# Reaction_CO_1.5h: avg=19.17, std=8.25
# Reaction_CO_biphenyl: avg=17.73, std=9.63
# Reaction_CO_ortho: avg=16.53, std=6.15
# Reaction_CO_Cl: avg=15.65, std=6.97
# Reaction_CS: avg=20.22, std=15.65
# Reaction_CN: avg=7.02, std=5.55
# Reaction_2+2: avg=21.87, std=8.48
# Reaction_CF3: avg=25.93, std=12.71
# Reaction_CH2CF3: avg=20.47, std=9.16
# Reaction_CH2F: avg=16.90, std=7.63
# Reaction_Cy: avg=24.45, std=11.15
# Reaction_SCF3: avg=18.97, std=9.07
# Reaction_OCH2F: avg=9.43, std=5.72
# Reaction_P: avg=12.12, std=7.65
# Reaction_Si: avg=27.18, std=15.34

# %%
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3',
                  'Reaction_OCH2F', 'Reaction_P', 'Reaction_Si']
for data in All_data_names:
    df = pd.read_csv(f"../results/BOsearch_EI/BOsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# Reaction_CO_1.5h: avg=17.05, std=8.41
# Reaction_CO_biphenyl: avg=19.48, std=10.18
# Reaction_CO_ortho: avg=16.72, std=7.24
# Reaction_CO_Cl: avg=15.15, std=6.81
# Reaction_CS: avg=20.08, std=16.17
# Reaction_CN: avg=6.37, std=5.03
# Reaction_2+2: avg=21.07, std=9.23
# Reaction_CF3: avg=23.45, std=12.90
# Reaction_CH2CF3: avg=21.70, std=9.17
# Reaction_CH2F: avg=16.98, std=7.70
# Reaction_Cy: avg=19.10, std=9.19
# Reaction_SCF3: avg=19.43, std=9.71
# Reaction_OCH2F: avg=10.02, std=6.09
# Reaction_P: avg=12.12, std=7.30
# Reaction_Si: avg=24.53, std=14.99

# %%
All_data_names = ['Reaction_CO_1.5h', 'Reaction_CO_biphenyl', 'Reaction_CO_ortho', 'Reaction_CO_Cl',
                  'Reaction_CS', 'Reaction_CN', 'Reaction_2+2',
                  'Reaction_CF3', 'Reaction_CH2CF3', 'Reaction_CH2F', 'Reaction_Cy', 'Reaction_SCF3',
                  'Reaction_OCH2F', 'Reaction_P', 'Reaction_Si']
for data in All_data_names:
    df = pd.read_csv(f"../results/BOsearch_UCB/BOsearch_{data}_result.csv")
    step_indices = []
    for row in df['actual_rewards_per_step']:
        rewards = ast.literal_eval(row)
        max_val = max(rewards)
        first_max_index = rewards.index(max_val) + 1
        step_indices.append(first_max_index)
    average_step_to_best = np.mean(step_indices)
    std_step_to_best = np.std(step_indices)

    print(f"{data}: avg={average_step_to_best:.2f}, std={std_step_to_best:.2f}")
# Out:
# Reaction_CO_1.5h: avg=13.52, std=8.12
# Reaction_CO_biphenyl: avg=29.73, std=10.25
# Reaction_CO_ortho: avg=18.03, std=8.00
# Reaction_CO_Cl: avg=14.10, std=6.05
# Reaction_CS: avg=19.48, std=15.45
# Reaction_CN: avg=7.00, std=5.99
# Reaction_2+2: avg=22.63, std=10.15
# Reaction_CF3: avg=23.95, std=12.38
# Reaction_CH2CF3: avg=24.28, std=10.69
# Reaction_CH2F: avg=18.13, std=8.27
# Reaction_Cy: avg=17.83, std=8.11
# Reaction_SCF3: avg=22.90, std=10.85
# Reaction_OCH2F: avg=11.17, std=6.19
# Reaction_P: avg=13.43, std=7.26
# Reaction_Si: avg=26.43, std=15.56
