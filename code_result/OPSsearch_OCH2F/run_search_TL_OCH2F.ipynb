# %%
from ModelbaseSearch_TL import TrABsearch

# %%
for data in ['Reaction_OCH2F']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=1, result_dir="../results/TrABsearch_top1_e0_ne5")
# Out:
# Running TrABsearch for Reaction_OCH2F...

# %%
for data in ['Reaction_OCH2F']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=3, result_dir="../results/TrABsearch_top3_e0_ne5")
# Out:
# Running TrABsearch for Reaction_OCH2F...

# %%
for data in ['Reaction_OCH2F']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=5, result_dir="../results/TrABsearch_top5_e0_ne5")
# Out:
# Running TrABsearch for Reaction_OCH2F...

# %%
for data in ['Reaction_OCH2F']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=3, selection_order='top', n_source=3, result_dir="../results/TrABsearch_top3_e0_ne3")
# Out:
# Running TrABsearch for Reaction_OCH2F...

# %%
for data in ['Reaction_OCH2F']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=10, selection_order='top', n_source=3, result_dir="../results/TrABsearch_top3_e0_ne10")
# Out:
# Running TrABsearch for Reaction_OCH2F...

# %%
for data in ['Reaction_OCH2F']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=5, selection_order='bottom', n_source=3, result_dir="../results/TrABsearch_bottom3_e0_ne5")
# Out:
# Running TrABsearch for Reaction_OCH2F...

# %%
for data in ['Reaction_OCH2F']:
    TrABsearch(target=data, n_OPS=60, epsilon=0, ne=5, selection_order='top', n_source=12, result_dir="../results/TrABsearch_all_e0_ne5")
# Out:
# Running TrABsearch for Reaction_OCH2F...

# %%
for data in ['Reaction_OCH2F']:
    TrABsearch(target=data, n_OPS=60, epsilon=0.1, ne=5, selection_order='top', n_source=3, result_dir="../results/TrABsearch_top3_e10%_ne5")
# Out:
# Running TrABsearch for Reaction_OCH2F...
